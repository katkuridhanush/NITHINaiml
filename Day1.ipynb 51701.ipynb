# %%
b = [1,2,3]

a = [2,4,6]

# %%
print(b+a)
# Out:
# [1, 2, 3, 2, 4, 6]

# %%
import numpy as np

# %%
a1=np.array(a)
b1=np.array(b)
print(a1+b1)
# Out:
# [3 6 9]

# %%
print(a1**2)
# Out:
# [ 4 16 36]

# %%
a1=np.array(a)
print(a1)
# Out:
# [2 4 6]

# %%
print(np.mean(a1))
# Out:
# 4.0

# %%
a2=[[1,2,3],[2,3,5],[7,8,9]]

# %%
print(np.diagonal(a2))
# Out:
# [1 3 9]

# %%
a3=np.array(a2)
print(a3)
# Out:
# [[1 2 3]
#  [2 3 5]
#  [7 8 9]]

# %%
print(a3.shape)
# Out:
# (3, 3)

# %%
print(np.diagonal(a3))
# Out:
# [1 3 9]

# %%
print(np.linalg.det(a3))
# Out:
# 6.0

# %% [markdown]
# print(np.linalg.inv(a3))

# %% [markdown]
# print(np.linalg.inv(a3))

# %%
print(np.log(a3))
# Out:
# [[0.         0.69314718 1.09861229]
#  [0.69314718 1.09861229 1.60943791]
#  [1.94591015 2.07944154 2.19722458]]

# %%
x=[1,2,3,4,5]
y=[6,7,8,9,10]
import matplotlib.pyplot as plt

# %%
plt.plot(x,y)
plt.xlabel("this is x-axis")
plt.xlabel("this is y-axis")
plt.title("Nithin's Graph")
plt.plot(x,y,'r')
plt.scat(x,y,'r')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-74-bff793e111eb> in <cell line: 6>()
#       4 plt.title("Nithin's Graph")
#       5 plt.plot(x,y,'r')
# ----> 6 plt.scat(x,y,'r')
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'scat'

# %%
plt.pie(x+y)
plt.title("nithin's pie")
# Out:
# Text(0.5, 1.0, "nithin's pie")

# %%
import pandas as pd

# %%
d=pd.read_csv('/content/sample_data/california_housing_train.csv')

# %%
print(d)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
x=d['longitude']
y=d['median_house_value']
plt.plot(x,y)
plt.title('nithin')

# %%
x=d['longitude']
y=d['total_rooms']
plt.plot(x,y)
plt.title('nithin')
# Out:
# Text(0.5, 1.0, 'nithin')

# %%
x=d['longitude']
y=d['housing_median_age']
plt.plot(x,y)
plt.title('nithin')
# Out:
# Text(0.5, 1.0, 'nithin')

# %%
x=d['longitude']
y=d['total_bedrooms']
plt.plot(x,y)
plt.title('nithin')
# Out:
# Text(0.5, 1.0, 'nithin')

# %%
x=d['longitude']
y=d['population']
plt.plot(x,y)
plt.title('nithin')
# Out:
# Text(0.5, 1.0, 'nithin')

# %%
x=d['longitude']
y=d['median_income']
plt.plot(x,y)
plt.title('nithin')
# Out:
# Text(0.5, 1.0, 'nithin')
